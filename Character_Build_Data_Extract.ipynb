# %% [markdown]
# <a href="https://colab.research.google.com/github/Srayoshi-Mirza/Genshin-Impact-Data-Analysis/blob/main/Character_Build_Data_Extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests #taking the html from an URl
import bs4 #beautiful soup 4 = bs4 - if we are taking the url by request library then we are using bs4 to find the targetted element
import pandas as pd #store or showing the data in pandas

# %%
url = "https://gamewith.net/genshin-impact/article/show/22884?fbclid=IwAR1ZxchA1vshDPI6YpCZNwSXTPwN7CCwGU-1dAkhKxhG_7OjAGrboMKS0VY"
tabs = pd.read_html(url)

# %%
print(f'Total tables: {len(tabs)}')
# Out:
# Total tables: 7

# %%
for x in range(len(tabs)):
  print(tabs[x])
  print("\n\n")
# Out:
#            Character              Build                    Weapon  \
# 0             Albedo        Geo Sub-DPS          Cinnabar Spindle
# 1          Alhaitham         Dendro DPS  Light Of Foliar Incision
# 2              Ayaka           Cryo DPS     Mistsplitter Reforged
# 3              Ayaka     Burst Cryo DPS     Mistsplitter Reforged
# 4              Ayato          Hydro DPS       Haran Geppaku Futsu
# 5              Ayato            Support             Freedom-Sworn
# 6            Bennett            Support            Aquila Favonia
# 7            Bennett           Pyro DPS     Mistsplitter Reforged
# 8               Jean       Physical DPS            Aquila Favonia
# 9               Jean            Support             Freedom-Sworn
# 10             Kaeya       Physical DPS            Aquila Favonia
# 11             Kaeya            Support             Skyward Blade
# 12            Kazuha  Elemental Support             Freedom-Sworn
# ...

# %%
sword_tab = tabs[0]
sword_tabg = sword_tab.groupby('Character')
print(type(sword_tab))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sword_tab.head()
# Out:
#    Character           Build                    Weapon  \
# 0     Albedo     Geo Sub-DPS          Cinnabar Spindle
# 1  Alhaitham      Dendro DPS  Light Of Foliar Incision
# 2      Ayaka        Cryo DPS     Mistsplitter Reforged
# 3      Ayaka  Burst Cryo DPS     Mistsplitter Reforged
# 4      Ayato       Hydro DPS       Haran Geppaku Futsu
#
#                                         Artifact Set
# 0                    Husk of Opulent Dreams 4pc. Set
# 1                             Gilded Dreams 4pc. Set
# 2                          Blizzard Strayer 4pc. Set
# 3  Blizzard Strayer 2pc. Set  Noblesse Oblige 2pc...
# 4                     Echoes Of An Offering 4pc. Set

# %%
sword_tab.columns
# Out:
# Index(['Character', 'Build', 'Weapon', 'Artifact Set'], dtype='object')

# %%
print(type(sword_tabg))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
polearm_tab = tabs[1]
polearm_tab.head()
# Out:
#   Character                  Build                      Weapon  \
# 0   Candace      Elemental Support                Black Tassel
# 1   Candace              Hydro DPS               Staff Of Homa
# 2      Cyno  Electro DPS Aggravate  Staff Of The Scarlet Sands
# 3    Hu Tao               Pyro DPS               Staff of Homa
# 4      Mika                Support              Favonius Lance
#
#                        Artifact Set Unnamed: 4
# 0          Noblesse Oblige 4pc. Set        NaN
# 1           Heart Of Depth 4pc. Set        NaN
# 2          Thundering Fury 4pc. Set        NaN
# 3  Crimson Witch of Flames 4pc. Set        NaN
# 4          Noblesse Oblige 4pc. Set        NaN

# %%
catalyst_tab = tabs[2]
catalyst_tab.head()
# Out:
#   Character            Build                             Weapon  \
# 0    Baizhu  Support General                Jadefall's Splendor
# 1    Baizhu   Support Dendro                Jadefall's Splendor
# 2   Barbara          Support  Thrilling Tales of Dragon Slayers
# 3   Barbara        Bloom Bot         A Thousand Floating Dreams
# 4      Klee         Pyro DPS    Lost Prayer to the Sacred Winds
#
#                        Artifact Set
# 0  Any HP% 2pc. SetAny HP% 2pc. Set
# 1        Deepwood Memories 4pc. Set
# 2           Maiden Beloved 4pc. Set
# 3  Flower of Paradise Lost 4pc. Set
# 4  Crimson Witch of Flames 4pc. Set

# %%
claymore_tab = tabs[3]
claymore_tab.head()
# Out:
#   Character        Build                  Weapon  \
# 0    Beidou  Electro DPS  Beacon of the Reed Sea
# 1    Beidou      Support       Wolf's Gravestone
# 2  Chongyun     Cryo DPS       Wolf's Gravestone
# 3  Chongyun        Dehya                Pyro DPS
# 4   Support        Dehya                The Bell
#
#                                  Artifact Set                  Unnamed: 4
# 0   Thundering Fury 2pc. SetAny ATK% 2pc. Set                         NaN
# 1             Emblem of Severed Fate 4pc. Set                         NaN
# 2  Any ATK% 2pc. SetBlizzard Strayer 2pc. Set                         NaN
# 3                      Beacon Of The Reed Sea  Vourukasha's Glow 4pc. Set
# 4          Tenacity of the Millelith 4pc. Set                         NaN

# %%
bow_tab = tabs[4]
bow_tab.head()
# Out:
#   Character           Build             Weapon  \
# 0     Amber        Pyro DPS          Amos' Bow
# 1     Amber    Pyro Sub-DPS       Skyward Harp
# 2      Aloy        Cryo DPS   Thundering Pulse
# 3    Childe       Hydro DPS         Polar Star
# 4    Collei  Dendro Sub-DPS  Elegy For The End
#
#                                         Artifact Set Unnamed: 4
# 0                         Wanderer's Troupe 4pc. Set        NaN
# 1  Crimson Witch of Flames 2pc. Set Noblesse Obli...        NaN
# 2                          Blizzard Strayer 4pc. Set        NaN
# 3                             Nymph's Dream 4pc. Set        NaN
# 4                             Gilded Dreams 4pc. Set        NaN

# %%
# %cd /content/drive/My Drive/CSV
# Out:
# /content/drive/My Drive/CSV

# %%
sword_tab.to_excel('sword.xlsx',index=False)
polearm_tab.to_excel('polearm.xlsx',index=False)
catalyst_tab.to_excel('catalyst.xlsx',index=False)
claymore_tab.to_excel('claymore.xlsx',index=False)
bow_tab.to_excel('bow.xlsx',index=False)
#/content/gdrive/My Drive/df.csv'
